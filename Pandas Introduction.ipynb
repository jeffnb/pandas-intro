# %%
# First we import numpy and pandas.  The following is just convention for people working with packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## First let's get some data
#
# We will use the kaggle dataset for 80 cereals and their nutrition. The file is included with this repository.
#
# ### Importing
#
# Pandas has some impressive tools to import data.  One of the most common ones is `read_csv`

# %%
pd.read_csv?

# %%
df = pd.read_csv('cereal.csv', sep=',', header=0)

# %% [markdown]
# ## Now lets take a quick look and see if it imported correctly
#
# ### `head()` and `tail()`
# The `head()` method is really nice for a fast look at your data frame.  If you mess up the header row it will tell you really quickly. By default both `head()` and `tail()` return 5 rows by default
#
# ### `info()`
# `info()` lists the columns, tell you how many non-null values arein there, and the numpy type
#
# ### `describe()`
# Gives a really nice stats layout of the data

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
df.tail(2)
# Out:
#                    name mfr type  calories  protein  fat  sodium  fiber  \
# 75             Wheaties   G    C       100        3    1     200    3.0
# 76  Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 75   17.0       3     110        25      1     1.0  1.00  51.592193
# 76   16.0       8      60        25      1     1.0  0.75  36.187559

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
# name        77 non-null object
# mfr         77 non-null object
# type        77 non-null object
# calories    77 non-null int64
# protein     77 non-null int64
# fat         77 non-null int64
# sodium      77 non-null int64
# fiber       77 non-null float64
# carbo       77 non-null float64
# sugars      77 non-null int64
# potass      77 non-null int64
# vitamins    77 non-null int64
# shelf       77 non-null int64
# weight      77 non-null float64
# cups        77 non-null float64
# rating      77 non-null float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 9.8+ KB

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# min    -1.000000   -1.000000    0.000000   1.000000   0.500000   0.250000
# 25%     3.000000   40.000000   25.000000   1.000000   1.000000   0.670000
# 50%     7.000000   90.000000   25.000000   2.000000   1.000000   0.750000
# 75%    11.000000  120.000000   25.000000   3.000000   1.000000   1.000000
# max    15.000000  330.000000  100.000000   3.000000   1.500000   1.500000
#
#           rating
# count  77.000000
# mean   42.665705
# std    14.047289
# min    18.042851
# 25%    33.174094
# 50%    40.400208
# 75%    50.828392
# max    93.704912

# %% [markdown]
# ## Data Frame and Series
#
# ### Data Frames
#
# You can think of a DataFrame as a spreadsheet.  It has columns and rows containing the data.  Each row has an index and each column has some type of name.
#
# ### Series
#
# Series are a data type that is simply a series of values either a single row or a single column

# %%
df[0:5] #same as head
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %% [markdown]
# ## Getting at your data
#
# There are several ways to access data.

# %%
# Get a column by name
df['name']
# Out:
# 0                     100% Bran
# 1             100% Natural Bran
# 2                      All-Bran
# 3     All-Bran with Extra Fiber
# 4                Almond Delight
#                 ...
# 72                      Triples
# 73                         Trix
# 74                   Wheat Chex
# 75                     Wheaties
# 76          Wheaties Honey Gold
# Name: name, Length: 77, dtype: object

# %%
# Get a column by . access
df.name
# Out:
# 0                     100% Bran
# 1             100% Natural Bran
# 2                      All-Bran
# 3     All-Bran with Extra Fiber
# 4                Almond Delight
#                 ...
# 72                      Triples
# 73                         Trix
# 74                   Wheat Chex
# 75                     Wheaties
# 76          Wheaties Honey Gold
# Name: name, Length: 77, dtype: object

# %%
# If you slice a dataframe it returns the columns
df[0:4]
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912

# %%
# You can also skip
df[0:8:2]
# Out:
#              name mfr type  calories  protein  fat  sodium  fiber  carbo  \
# 0       100% Bran   N    C        70        4    1     130   10.0    5.0
# 2        All-Bran   K    C        70        4    1     260    9.0    7.0
# 4  Almond Delight   R    C       110        2    2     200    1.0   14.0
# 6     Apple Jacks   K    C       110        2    0     125    1.0   11.0
#
#    sugars  potass  vitamins  shelf  weight  cups     rating
# 0       6     280        25      3     1.0  0.33  68.402973
# 2       5     320        25      3     1.0  0.33  59.425505
# 4       8      -1        25      3     1.0  0.75  34.384843
# 6      14      30        25      2     1.0  1.00  33.174094

# %% [markdown]
# ### `iloc`

# %%
# iloc finds by position
df.iloc[0:3]
# Out:
#                 name mfr type  calories  protein  fat  sodium  fiber  carbo  \
# 0          100% Bran   N    C        70        4    1     130   10.0    5.0
# 1  100% Natural Bran   Q    C       120        3    5      15    2.0    8.0
# 2           All-Bran   K    C        70        4    1     260    9.0    7.0
#
#    sugars  potass  vitamins  shelf  weight  cups     rating
# 0       6     280        25      3     1.0  0.33  68.402973
# 1       8     135         0      3     1.0  1.00  33.983679
# 2       5     320        25      3     1.0  0.33  59.425505

# %%
# iloc finds by position
df.iloc[0:3, 0:3]
# Out:
#                 name mfr type
# 0          100% Bran   N    C
# 1  100% Natural Bran   Q    C
# 2           All-Bran   K    C

# %% [markdown]
# ### `loc` is by label

# %%
df.loc[0:3]
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912

# %%
df.loc[0:3, ['name', 'mfr', 'type']]
# Out:
#                         name mfr type
# 0                  100% Bran   N    C
# 1          100% Natural Bran   Q    C
# 2                   All-Bran   K    C
# 3  All-Bran with Extra Fiber   K    C

# %% [markdown]
# #### NOTE:  `ix` is deprecated so don't use

# %% [markdown]
# ### Filtering Items
#
#
# Most common way is using masks.  This is not as crazy as it sounds and often don't even see them.

# %%
# Notice how it returns ALL rows but with a True or False
df.mfr == 'N'
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 72    False
# 73    False
# 74    False
# 75    False
# 76    False
# Name: mfr, Length: 77, dtype: bool

# %%
# Let's drop that into the dataframe selection
df[df.mfr == 'N']
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 20     Cream of Wheat (Quick)   N    H       100        3    0      80    1.0
# 63             Shredded Wheat   N    C        80        2    0       0    3.0
# 64     Shredded Wheat 'n'Bran   N    C        90        3    0       0    4.0
# 65  Shredded Wheat spoon size   N    C        90        3    0       0    3.0
# 68    Strawberry Fruit Wheats   N    C        90        2    0      15    3.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     5.0       6     280        25      3    1.00  0.33  68.402973
# 20   21.0       0      -1         0      2    1.00  1.00  64.533816
# 63   16.0       0      95         0      1    0.83  1.00  68.235885
# 64   19.0       0     140         0      1    1.00  0.67  74.472949
# 65   20.0       0     120         0      1    1.00  0.67  72.801787
# 68   15.0       5      90        25      2    1.00  1.00  59.363993

# %%
# Want more specifics
df[(df.mfr == 'N') & (df.calories < 100)]
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 63             Shredded Wheat   N    C        80        2    0       0    3.0
# 64     Shredded Wheat 'n'Bran   N    C        90        3    0       0    4.0
# 65  Shredded Wheat spoon size   N    C        90        3    0       0    3.0
# 68    Strawberry Fruit Wheats   N    C        90        2    0      15    3.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     5.0       6     280        25      3    1.00  0.33  68.402973
# 63   16.0       0      95         0      1    0.83  1.00  68.235885
# 64   19.0       0     140         0      1    1.00  0.67  74.472949
# 65   20.0       0     120         0      1    1.00  0.67  72.801787
# 68   15.0       5      90        25      2    1.00  1.00  59.363993

# %% [markdown]
# ### Only want certain columns?
#
# Just pass a list in the same way you filtered

# %%
df[['name', 'mfr', 'type']].head()
# Out:
#                         name mfr type
# 0                  100% Bran   N    C
# 1          100% Natural Bran   Q    C
# 2                   All-Bran   K    C
# 3  All-Bran with Extra Fiber   K    C
# 4             Almond Delight   R    C

# %% [markdown]
# ### String searching

# %%
df[df.name.str.contains('Frosted', case=False)]
# Out:
#                    name mfr type  calories  protein  fat  sodium  fiber  \
# 25       Frosted Flakes   K    C       110        1    0     200    1.0
# 26  Frosted Mini-Wheats   K    C       100        3    0       0    3.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 25   14.0      11      25        25      1     1.0  0.75  31.435973
# 26   14.0       7     100        25      2     1.0  0.80  58.345141

# %% [markdown]
# ## Sorting time

# %%
df.sort_values(by='name', ascending=False)
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 72                    Triples   G    C       110        2    1     250    0.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 4              Almond Delight   R    C       110        2    2     200    1.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 0                   100% Bran   N    C        70        4    1     130   10.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 76   16.0       8      60        25      1     1.0  0.75  36.187559
# 75   17.0       3     110        25      1     1.0  1.00  51.592193
# 74   17.0       3     115        25      1     1.0  0.67  49.787445
# 73   13.0      12      25        25      2     1.0  1.00  27.753301
# 72   21.0       3      60        25      3     1.0  0.75  39.106174
# ..    ...     ...     ...       ...    ...     ...   ...        ...
# 4    14.0       8      -1        25      3     1.0  0.75  34.384843
# 3     8.0       0     330        25      3     1.0  0.50  93.704912
# 2     7.0       5     320        25      3     1.0  0.33  59.425505
# 1     8.0       8     135         0      3     1.0  1.00  33.983679
# 0     5.0       6     280        25      3     1.0  0.33  68.402973
#
# [77 rows x 16 columns]

# %%
df.sort_index(ascending=False)
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 72                    Triples   G    C       110        2    1     250    0.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 4              Almond Delight   R    C       110        2    2     200    1.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 0                   100% Bran   N    C        70        4    1     130   10.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 76   16.0       8      60        25      1     1.0  0.75  36.187559
# 75   17.0       3     110        25      1     1.0  1.00  51.592193
# 74   17.0       3     115        25      1     1.0  0.67  49.787445
# 73   13.0      12      25        25      2     1.0  1.00  27.753301
# 72   21.0       3      60        25      3     1.0  0.75  39.106174
# ..    ...     ...     ...       ...    ...     ...   ...        ...
# 4    14.0       8      -1        25      3     1.0  0.75  34.384843
# 3     8.0       0     330        25      3     1.0  0.50  93.704912
# 2     7.0       5     320        25      3     1.0  0.33  59.425505
# 1     8.0       8     135         0      3     1.0  1.00  33.983679
# 0     5.0       6     280        25      3     1.0  0.33  68.402973
#
# [77 rows x 16 columns]

# %% [markdown]
# ## Lets change the data

# %% [markdown]
# ## Quick Reindexing

# %%
# Quick copy
df_reindexed = df.copy()

# %%
# Set the index
df_reindexed.index = df_reindexed['name']
df_reindexed.head()
# Out:
#                                                 name mfr type  calories  \
# name
# 100% Bran                                  100% Bran   N    C        70
# 100% Natural Bran                  100% Natural Bran   Q    C       120
# All-Bran                                    All-Bran   K    C        70
# All-Bran with Extra Fiber  All-Bran with Extra Fiber   K    C        50
# Almond Delight                        Almond Delight   R    C       110
#
#                            protein  fat  sodium  fiber  carbo  sugars  potass  \
# name
# 100% Bran                        4    1     130   10.0    5.0       6     280
# 100% Natural Bran                3    5      15    2.0    8.0       8     135
# All-Bran                         4    1     260    9.0    7.0       5     320
# All-Bran with Extra Fiber        4    0     140   14.0    8.0       0     330
# Almond Delight                   2    2     200    1.0   14.0       8      -1
#
#                            vitamins  shelf  weight  cups     rating
# name
# 100% Bran                        25      3     1.0  0.33  68.402973
# 100% Natural Bran                 0      3     1.0  1.00  33.983679
# All-Bran                         25      3     1.0  0.33  59.425505
# All-Bran with Extra Fiber        25      3     1.0  0.50  93.704912
# Almond Delight                   25      3     1.0  0.75  34.384843

# %%
# Drop the name column since it is the index now
df_reindexed = df_reindexed.drop('name', axis=1)
df_reindexed.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0       6     280        25      3     1.0
# 100% Natural Bran            8.0       8     135         0      3     1.0
# All-Bran                     7.0       5     320        25      3     1.0
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Almond Delight              14.0       8      -1        25      3     1.0
#
#                            cups     rating
# name
# 100% Bran                  0.33  68.402973
# 100% Natural Bran          1.00  33.983679
# All-Bran                   0.33  59.425505
# All-Bran with Extra Fiber  0.50  93.704912
# Almond Delight             0.75  34.384843

# %%
df_reindexed.head()

# %%
df_reindexed.loc['All-Bran':'Almond Delight']
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# All-Bran                     7.0       5     320        25      3     1.0
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Almond Delight              14.0       8      -1        25      3     1.0
#
#                            cups     rating
# name
# All-Bran                   0.33  59.425505
# All-Bran with Extra Fiber  0.50  93.704912
# Almond Delight             0.75  34.384843

# %% [markdown]
# ### Let's fix the -1 in the columns.
#
# An easier way to do this would be on import

# %%
columns = ["calories", "protein", "fat", "sodium", "fiber", "carbo", "sugars", "potass", "vitamins", "shelf", "weight"]

# %%
df_reindexed[columns] = df_reindexed[columns].replace(-1, np.NaN)

# %%
df_reindexed.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0     6.0   280.0        25      3     1.0
# 100% Natural Bran            8.0     8.0   135.0         0      3     1.0
# All-Bran                     7.0     5.0   320.0        25      3     1.0
# All-Bran with Extra Fiber    8.0     0.0   330.0        25      3     1.0
# Almond Delight              14.0     8.0     NaN        25      3     1.0
#
#                            cups     rating
# name
# 100% Bran                  0.33  68.402973
# 100% Natural Bran          1.00  33.983679
# All-Bran                   0.33  59.425505
# All-Bran with Extra Fiber  0.50  93.704912
# Almond Delight             0.75  34.384843

# %% [markdown]
# ### Replace a specific item

# %%
df_reindexed.at['Almond Delight', 'potass'] = 300

# %%
df_reindexed.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0     6.0   280.0        25      3     1.0
# 100% Natural Bran            8.0     8.0   135.0         0      3     1.0
# All-Bran                     7.0     5.0   320.0        25      3     1.0
# All-Bran with Extra Fiber    8.0     0.0   330.0        25      3     1.0
# Almond Delight              14.0     8.0   300.0        25      3     1.0
#
#                            cups     rating
# name
# 100% Bran                  0.33  68.402973
# 100% Natural Bran          1.00  33.983679
# All-Bran                   0.33  59.425505
# All-Bran with Extra Fiber  0.50  93.704912
# Almond Delight             0.75  34.384843

# %% [markdown]
# ## Stats Watch your numbers
#
# Remember `df` has all original values.  `df_reindexed` we replaced -1 with `np.NaN`

# %%
df.sugars.mean()
# Out:
# 6.922077922077922

# %%
df_reindexed.sugars.mean()
# Out:
# 7.026315789473684

# %% [markdown]
# ## Graphs are good

# %%
df.sugars.plot(kind="hist")

# %%
df.calories.plot(kind="hist")

# %%
plt.scatter(df.calories, df.sugars)

# %% [markdown]
# ## Let's Fill out mfr
#
# The letters aren't great so lets also add a full manufacturer name

# %%
# First the dictionary.  Already here for you
mfrs = {'A': 'American Home Food Products', 
        'G': 'General Mills', 
        'K': 'Kelloggs',
        'N': 'Nabisco',
        'P': 'Post',
        'Q': 'Quaker Oats',
        'R': 'Ralston Purina'}

# %%
# Now lets use replace get a new column
df.mfr.replace(mfrs)
# Out:
# 0            Nabisco
# 1        Quaker Oats
# 2           Kelloggs
# 3           Kelloggs
# 4     Ralston Purina
#            ...
# 72     General Mills
# 73     General Mills
# 74    Ralston Purina
# 75     General Mills
# 76     General Mills
# Name: mfr, Length: 77, dtype: object

# %%
df['mfr_full'] = df.mfr.replace(mfrs)

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating  \
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843
#
#          mfr_full
# 0         Nabisco
# 1     Quaker Oats
# 2        Kelloggs
# 3        Kelloggs
# 4  Ralston Purina

# %% [markdown]
# ## A simple groupby

# %%
df.groupby(by=['mfr_full']).mean()
# Out:
#                                calories   protein       fat      sodium  \
# mfr_full
# American Home Food Products  100.000000  4.000000  1.000000    0.000000
# General Mills                111.363636  2.318182  1.363636  200.454545
# Kelloggs                     108.695652  2.652174  0.608696  174.782609
# Nabisco                       86.666667  2.833333  0.166667   37.500000
# Post                         108.888889  2.444444  0.888889  146.111111
# Quaker Oats                   95.000000  2.625000  1.750000   92.500000
# Ralston Purina               115.000000  2.500000  1.250000  198.125000
#
#                                 fiber      carbo    sugars      potass  \
# mfr_full
# American Home Food Products  0.000000  16.000000  3.000000   95.000000
# General Mills                1.272727  14.727273  7.954545   85.227273
# Kelloggs                     2.739130  15.130435  7.565217  103.043478
# Nabisco                      4.000000  16.000000  1.833333  120.666667
# Post                         2.777778  13.222222  8.777778  113.888889
# Quaker Oats                  1.337500  10.000000  5.250000   74.375000
# Ralston Purina               1.875000  17.625000  6.125000   89.250000
#
#                               vitamins     shelf    weight      cups  \
# mfr_full
# American Home Food Products  25.000000  2.000000  1.000000  1.000000
# General Mills                35.227273  2.136364  1.049091  0.875000
# Kelloggs                     34.782609  2.347826  1.077826  0.796087
# Nabisco                       8.333333  1.666667  0.971667  0.778333
# Post                         25.000000  2.444444  1.064444  0.714444
# Quaker Oats                  12.500000  2.375000  0.875000  0.823750
# Ralston Purina               25.000000  2.000000  1.000000  0.871250
#
#                                 rating
# mfr_full
# American Home Food Products  54.850917
# General Mills                34.485852
# Kelloggs                     44.038462
# Nabisco                      67.968567
# Post                         41.705744
# Quaker Oats                  42.915990
# Ralston Purina               41.542997

# %% [markdown]
# ## Apply
#
# Sometimes you need to do calculations to transform the data in a column to something else.  Pandas allows for a function call with the values to transform them.

# %%
# For example potass and sodium are measured in mg not g like the other measurements.  
# Lets change sodium to grams

df.sodium.apply(lambda x: x/1000)
# Out:
# 0     0.130
# 1     0.015
# 2     0.260
# 3     0.140
# 4     0.200
#       ...
# 72    0.250
# 73    0.140
# 74    0.230
# 75    0.200
# 76    0.200
# Name: sodium, Length: 77, dtype: float64

# %%
df['sodium_g'] = df.sodium.apply(lambda x: x/1000)

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating  \
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843
#
#          mfr_full  sodium_g
# 0         Nabisco     0.130
# 1     Quaker Oats     0.015
# 2        Kelloggs     0.260
# 3        Kelloggs     0.140
# 4  Ralston Purina     0.200

# %% [markdown]
# ### More complex apply method
#
# We can do more complex things to entire rows.  Let's standardize the values so EVERYTHING is based on 1 cup serving size.

# %%
df_std = df.copy()

# %%
def standardize(row):
    # first get multiplier for the cup
    multi = 1/row.cups
    
    # columns we care about
    columns = ['calories', 'protein', 'fat', 'sodium', 'fiber', 'carbo', 'sugars', 'potass', 'vitamins', 'cups']
    row[columns] = row[columns] * multi
    return row
    
df_std = df_std.apply(standardize, axis=1)

# %%
df_std.head()
# Out:
#                         name mfr type    calories    protein       fat  \
# 0                  100% Bran   N    C  212.121212  12.121212  3.030303
# 1          100% Natural Bran   Q    C  120.000000   3.000000  5.000000
# 2                   All-Bran   K    C  212.121212  12.121212  3.030303
# 3  All-Bran with Extra Fiber   K    C  100.000000   8.000000  0.000000
# 4             Almond Delight   R    C  146.666667   2.666667  2.666667
#
#        sodium      fiber      carbo     sugars      potass   vitamins  shelf  \
# 0  393.939394  30.303030  15.151515  18.181818  848.484848  75.757576      3
# 1   15.000000   2.000000   8.000000   8.000000  135.000000   0.000000      3
# 2  787.878788  27.272727  21.212121  15.151515  969.696970  75.757576      3
# 3  280.000000  28.000000  16.000000   0.000000  660.000000  50.000000      3
# 4  266.666667   1.333333  18.666667  10.666667   -1.333333  33.333333      3
#
#    weight  cups     rating        mfr_full  sodium_g
# 0     1.0   1.0  68.402973         Nabisco     0.130
# 1     1.0   1.0  33.983679     Quaker Oats     0.015
# 2     1.0   1.0  59.425505        Kelloggs     0.260
# 3     1.0   1.0  93.704912        Kelloggs     0.140
# 4     1.0   1.0  34.384843  Ralston Purina     0.200

# %%
plt.scatter(df_std.calories, df_std.sugars)

# %%
df_std.sort_values('calories', ascending=False)[0:5]
# Out:
#                     name mfr type    calories    protein       fat  \
# 33            Grape-Nuts   P    C  440.000000  12.000000  0.000000
# 34    Great Grains Pecan   P    C  363.636364   9.090909  9.090909
# 51  Oatmeal Raisin Crisp   G    C  260.000000   6.000000  4.000000
# 46  Mueslix Crispy Blend   K    C  238.805970   4.477612  2.985075
# 13              Clusters   G    C  220.000000   6.000000  4.000000
#
#         sodium      fiber      carbo     sugars      potass    vitamins  \
# 33  680.000000  12.000000  68.000000  12.000000  360.000000  100.000000
# 34  227.272727   9.090909  39.393939  12.121212  303.030303   75.757576
# 51  340.000000   3.000000  27.000000  20.000000  240.000000   50.000000
# 46  223.880597   4.477612  25.373134  19.402985  238.805970   37.313433
# 13  280.000000   4.000000  26.000000  14.000000  210.000000   50.000000
#
#     shelf  weight  cups     rating       mfr_full  sodium_g
# 33      3    1.00   1.0  53.371007           Post     0.170
# 34      3    1.00   1.0  45.811716           Post     0.075
# 51      3    1.25   1.0  30.450843  General Mills     0.170
# 46      3    1.50   1.0  30.313351       Kelloggs     0.150
# 13      3    1.00   1.0  40.400208  General Mills     0.140

# %%
plt.scatter(df_std[df_std.calories < 300].calories, df_std[df_std.calories < 300].sugars)

# %%
df_std[df_std.calories < 300]

# %% [markdown]
# ## Merge
#
# Merging is similar to SQL with specifying which join to use

# %%
pd.merge(df, df_std, on="name")
# Out:
#                          name mfr_x type_x  calories_x  protein_x  fat_x  \
# 0                   100% Bran     N      C          70          4      1
# 1           100% Natural Bran     Q      C         120          3      5
# 2                    All-Bran     K      C          70          4      1
# 3   All-Bran with Extra Fiber     K      C          50          4      0
# 4              Almond Delight     R      C         110          2      2
# ..                        ...   ...    ...         ...        ...    ...
# 72                    Triples     G      C         110          2      1
# 73                       Trix     G      C         110          1      1
# 74                 Wheat Chex     R      C         100          3      1
# 75                   Wheaties     G      C         100          3      1
# 76        Wheaties Honey Gold     G      C         110          2      1
#
#     sodium_x  fiber_x  carbo_x  sugars_x  ...    carbo_y   sugars_y  \
# 0        130     10.0      5.0         6  ...  15.151515  18.181818
# 1         15      2.0      8.0         8  ...   8.000000   8.000000
# 2        260      9.0      7.0         5  ...  21.212121  15.151515
# 3        140     14.0      8.0         0  ...  16.000000   0.000000
# 4        200      1.0     14.0         8  ...  18.666667  10.666667
# ..       ...      ...      ...       ...  ...        ...        ...
# 72       250      0.0     21.0         3  ...  28.000000   4.000000
# 73       140      0.0     13.0        12  ...  13.000000  12.000000
# 74       230      3.0     17.0         3  ...  25.373134   4.477612
# 75       200      3.0     17.0         3  ...  17.000000   3.000000
# 76       200      1.0     16.0         8  ...  21.333333  10.666667
#
#       potass_y  vitamins_y  shelf_y  weight_y cups_y   rating_y  \
# 0   848.484848   75.757576        3       1.0    1.0  68.402973
# 1   135.000000    0.000000        3       1.0    1.0  33.983679
# 2   969.696970   75.757576        3       1.0    1.0  59.425505
# 3   660.000000   50.000000        3       1.0    1.0  93.704912
# 4    -1.333333   33.333333        3       1.0    1.0  34.384843
# ..         ...         ...      ...       ...    ...        ...
# 72   80.000000   33.333333        3       1.0    1.0  39.106174
# 73   25.000000   25.000000        2       1.0    1.0  27.753301
# 74  171.641791   37.313433        1       1.0    1.0  49.787445
# 75  110.000000   25.000000        1       1.0    1.0  51.592193
# 76   80.000000   33.333333        1       1.0    1.0  36.187559
#
#         mfr_full_y sodium_g_y
# 0          Nabisco      0.130
# 1      Quaker Oats      0.015
# 2         Kelloggs      0.260
# 3         Kelloggs      0.140
# 4   Ralston Purina      0.200
# ..             ...        ...
# 72   General Mills      0.250
# 73   General Mills      0.140
# 74  Ralston Purina      0.230
# 75   General Mills      0.200
# 76   General Mills      0.200
#
# [77 rows x 35 columns]
